# %% [markdown]
# # Proyek Analisis Data: E-commerce Public Dataset
# - **Nama:** Yuwanda Aji Pangestu
# - **Email:** yuwandaaji657@gmail.com
# - **ID Dicoding:** yuwandaajipangestu

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana performa pesanan dalam beberapa bulan?
# - Tipe produk apa yang paling banyak dan paling sedikit dipesan?
# - Wilayah mana yang memiliki penjual paling banyak?
# - Bagaimana performa dari penjual terbaik?
# - Wilayah mana yang memiliki pelanggan paling banyak?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
customers = pd.read_csv("customers_dataset.csv")
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
order_items = pd.read_csv("order_items_dataset.csv")
order_items.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_payments = pd.read_csv("order_payments_dataset.csv")
order_payments.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
order_review = pd.read_csv("order_reviews_dataset.csv")
order_review.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
order = pd.read_csv("orders_dataset.csv")
order.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
product_category = pd.read_csv("product_category_name_translation.csv")
product_category.head()
# Out:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor

# %%
product = pd.read_csv("products_dataset.csv")
product.head()
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
sellers = pd.read_csv("sellers_dataset.csv")
sellers.head()
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# **Insight:**
# - Pada tabel Customer terdapat informasi berguna yang tersedia pada kolom customer_id, customer_city, dan customer_state
# - Pada tabel order_items terdapat informasi berguna yang tersedia pada kolom customer_id, product_id, seller_id, price,dan freight_value
# - Pada tabel order_payments terdapat informasi berguna yang tersedia pada kolom order_id dan payment_value
# - Pada tabel order_review terdapat informasi berguna yang tersedia pada kolom order_id dan review_score
# - Pada tabel order terdapat informasi berguna yang tersedia pada kolom order_id, customer_id, order_status, dan order_purchase_timestamp
# - Pada tabel product_category terdapat informasi berguna yang tersedia pada kolom product_category_name dan 	product_category_name_english
# - Pada tabel product terdapat informasi berguna yang tersedia pada kolom product_id dan product_category_name
# - Pada tabel sellers terdapat informasi berguna yang tersedia pada kolom seller_id, seller_city, dan seller_state

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# **Menilai Tabel `customers`**

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
print("Jumlah Duplikasi: ", customers.duplicated().sum())
# Out:
# Jumlah Duplikasi:  0

# %%
customers.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %% [markdown]
# **Menilai Tabel `order_items`**

# %%
order_items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
print("Jumlah Duplikasi: ", order_items.duplicated().sum())
# Out:
# Jumlah Duplikasi:  0

# %%
order_items.describe(include="all")
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# std                                  NaN       0.705124
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %% [markdown]
# **Menilai Tabel `order_payments`**

# %%
order_payments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
print("Jumlah Duplikasi: ", order_payments.duplicated().sum())
# Out:
# Jumlah Duplikasi:  0

# %%
order_payments.describe(include="all")
# Out:
#                                 order_id  payment_sequential payment_type  \
# count                             103886       103886.000000       103886
# unique                             99440                 NaN            5
# top     fa65dad1b0e818e3ccc5cb0e39231352                 NaN  credit_card
# freq                                  29                 NaN        76795
# mean                                 NaN            1.092679          NaN
# std                                  NaN            0.706584          NaN
# min                                  NaN            1.000000          NaN
# 25%                                  NaN            1.000000          NaN
# 50%                                  NaN            1.000000          NaN
# 75%                                  NaN            1.000000          NaN
# max                                  NaN           29.000000          NaN
#
#         payment_installments  payment_value
# ...

# %% [markdown]
# **Menilai Tabel `order_review`**

# %%
order_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  object
#  1   order_id                 99224 non-null  object
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  object
#  4   review_comment_message   40977 non-null  object
#  5   review_creation_date     99224 non-null  object
#  6   review_answer_timestamp  99224 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
print("Jumlah Duplikasi: ", order_review.duplicated().sum())
# Out:
# Jumlah Duplikasi:  0

# %%
order_review.isna().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
order_review.describe(include="all")
# Out:
#                                review_id                          order_id  \
# count                              99224                             99224
# unique                             98410                             98673
# top     7b606b0d57b078384f0b58eac1d41d78  c88b1d1b157a9999ce368f218a407141
# freq                                   3                                 3
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         review_score review_comment_title review_comment_message  \
# ...

# %% [markdown]
# **Menilai Tabel `order`**

# %%
order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
print("Jumlah Duplikasi: ", order.duplicated().sum())
# Out:
# Jumlah Duplikasi:  0

# %%
order.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %%
order.describe(include="all")
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-04-11 10:48:14  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# ...

# %% [markdown]
# **Menilai Tabel `product_category`**

# %%
product_category.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     object
#  1   product_category_name_english  71 non-null     object
# dtypes: object(2)
# memory usage: 1.2+ KB

# %%
print("Jumlah Duplikasi: ", product_category.duplicated().sum())
# Out:
# Jumlah Duplikasi:  0

# %%
product_category.describe(include="all")
# Out:
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %% [markdown]
# **Menilai Tabel `product`**

# %%
product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
print("Jumlah Duplikasi: ", product.duplicated().sum())
# Out:
# Jumlah Duplikasi:  0

# %%
product.isna().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %%
product.describe(include="all")
# Out:
#                               product_id product_category_name  \
# count                              32951                 32341
# unique                             32951                    73
# top     1e9e8ef04dbcff4541ed26657ea517e5       cama_mesa_banho
# freq                                   1                  3029
# mean                                 NaN                   NaN
# std                                  NaN                   NaN
# min                                  NaN                   NaN
# 25%                                  NaN                   NaN
# 50%                                  NaN                   NaN
# 75%                                  NaN                   NaN
# max                                  NaN                   NaN
#
#         product_name_lenght  product_description_lenght  product_photos_qty  \
# count          32341.000000                32341.000000        32341.000000
# ...

# %% [markdown]
# **Menilai Tabel `Sellers`**

# %%
sellers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %%
print("Jumlah Duplikasi: ", sellers.duplicated().sum())
# Out:
# Jumlah Duplikasi:  0

# %%
sellers.describe(include="all")
# Out:
#                                seller_id  seller_zip_code_prefix seller_city  \
# count                               3095             3095.000000        3095
# unique                              3095                     NaN         611
# top     3442f8959a84dea7ee197c632cb2df15                     NaN   sao paulo
# freq                                   1                     NaN         694
# mean                                 NaN            32291.059451         NaN
# std                                  NaN            32713.453830         NaN
# min                                  NaN             1001.000000         NaN
# 25%                                  NaN             7093.500000         NaN
# 50%                                  NaN            14940.000000         NaN
# 75%                                  NaN            64552.500000         NaN
# max                                  NaN            99730.000000         NaN
#
#        seller_state
# count          3095
# ...

# %% [markdown]
# **Insight:**
# - Tabel `customers` tidak memiliki masalah apa pun
# - Tabel `order_items` memiliki kesalahan tipe pada kolom shipping_limit_date yang seharusnya bertipe datetime. Namun, sebenarnya kolom tersebut tidak terlalu berguna
# - Tabel `order_payments` tidak memiliki masalah apapun
# - Tabel `order_review` memiliki permasalahan missing value pada kolom review_comment_title dan review_comment_message. Tabel `order_review` juga memiliki kesalahan tipe pada kolom review_creation_date dan review_answer_timestamp yang seharusnya bertipe datetime. Kolom-kolom yang bermasalah tersebut sebenarnya tidak memiliki kegunaan untuk menjawab pertanyaan analysis.
# - Tabel `order` memiliki permasalahan missing value pada kolom order_approved_at, order_delivered_carrier_date, dan order_delivered_customer_date. Tabel `order` juga memiliki kesalahan tipe pada kolom order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, dan order_delivered_customer_date, dan order_estimated_delivery_date yang seharusnya bertipe datetime
# - Tabel `product_category` tidak memiliki masalah apapun
# - Tabel `product` memiliki permasalahan missing value pada kolom product_category_name, product_name_lenght, product_description_lenght, product_photos_qty, product_weight_g, product_length_cm, product_height_cm, product_width_cm
# - Tabel `sellers` tidak memiliki masalah apapun

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# **Membersihkan Tabel `order_items`**

# %% [markdown]
# Membuang Kolom yang Tidak Diperlukan

# %%
order_items.drop(columns=["shipping_limit_date"], axis=1, inplace=True)

# %%
order_items.describe(include="all")
# Out:
#                                 order_id  order_item_id  \
# count                             112650  112650.000000
# unique                             98666            NaN
# top     8272b63d03f5f79c56e9e4120aec44ef            NaN
# freq                                  21            NaN
# mean                                 NaN       1.197834
# std                                  NaN       0.705124
# min                                  NaN       1.000000
# 25%                                  NaN       1.000000
# 50%                                  NaN       1.000000
# 75%                                  NaN       1.000000
# max                                  NaN      21.000000
#
#                               product_id                         seller_id  \
# count                             112650                            112650
# unique                             32951                              3095
# ...

# %% [markdown]
# **Membersihkan Tabel `order_review`**

# %% [markdown]
# Membuang Kolom yang Tidak Diperlukan

# %%
order_review.drop(columns=['review_comment_title','review_comment_message','review_creation_date','review_answer_timestamp'],index=1,inplace=True)

# %%
order_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 99223 entries, 0 to 99223
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   review_id     99223 non-null  object
#  1   order_id      99223 non-null  object
#  2   review_score  99223 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 3.0+ MB

# %%
order_review.describe(include="all")
# Out:
#                                review_id                          order_id  \
# count                              99223                             99223
# unique                             98409                             98672
# top     abbfacb2964f74f6487c9c10ac46daa6  03c939fd7fd3b38f8485a0f95798f1f6
# freq                                   3                                 3
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         review_score
# count   99223.000000
# unique           NaN
# ...

# %% [markdown]
# **Membersihkan Tabel `order`**

# %% [markdown]
# Membuang Kolom yang Tidak Diperlukan

# %%
order.drop(columns=["order_approved_at", "order_delivered_carrier_date", "order_delivered_customer_date", "order_estimated_delivery_date"], axis=1, inplace=True)

# %% [markdown]
# Memperbaiki Tipe Data

# %%
datetime_column = ["order_purchase_timestamp"]

for column in datetime_column:
    order[column] = pd.to_datetime(order[column])

# %%
order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   order_id                  99441 non-null  object
#  1   customer_id               99441 non-null  object
#  2   order_status              99441 non-null  object
#  3   order_purchase_timestamp  99441 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(3)
# memory usage: 3.0+ MB

# %% [markdown]
# **Membersihkan Tabel `product`**

# %% [markdown]
# Membuang Kolom yang Tidak Diperlukan

# %%
product.drop(columns=["product_name_lenght","product_description_lenght","product_photos_qty","product_weight_g","product_length_cm","product_height_cm","product_width_cm"], index=1, inplace=True)

# %% [markdown]
# Missing Value

# %%
product.isna().sum() * 100/len(product)
# Out:
# product_id               0.00000
# product_category_name    1.85129
# dtype: float64

# %%
product.dropna(inplace=True)

# %%
product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32340 entries, 0 to 32950
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   product_id             32340 non-null  object
#  1   product_category_name  32340 non-null  object
# dtypes: object(2)
# memory usage: 758.0+ KB

# %% [markdown]
# **Insight:**
# - Pada Tabel `order_items` permasalahan tentang kesalahan tipe pada kolom shipping_limit_date lebih baik diselesaikan dengan membuang kolom tersebut karena kolom itu tidak akan berguna untuk menjawab pertanyaan analisis
# - Pada Tabel `order_review` permasalahan tentang missing value dan kesalahan tipe telah diselesaikan dengan membuang kolom-kolom yang bermasalah tersebut. Hal itu dilakukan karena kolom-kolom itu tidak berguna untuk menjawab pertanyaan analisis
# - Pada Tabel `order` langkah pembersihan pertama adalah membuang kolom-kolom yang tidak diperlukan. Hal itu secara tidak langsung menyelesaikan permasalahan missing value karena kolom yang memiliki permasalahan tersebut juga termasuk ke dalam kategori kolom yang tidak diperlukan. Dari langkah itu telah menyisakan satu kolom bermasalah, yaitu kolom order_purchase_timestamp  yang memiliki kesalahan tipe. Permasalahan itu kemudian diperbaiki dengan merubah tipe kolom tersebut menjadi datetime
# - Pada Tabel `product` langkah pembersihan pertama adalah membuang kolom-kolom yang tidak diperlukan. Dengan begitu, kolom yang memiliki masalah missing value hanya tinggal kolom product_category_name. permasalah kolom itu telah diselesaikan dengan cara membuang data null karena data null tersebut hanya kurang dari 5% dari keseluruhan data

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ##Explore `customers`

# %%
customers.describe(include="all")
# Out:
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
# mean                                 NaN                               NaN
# std                                  NaN                               NaN
# min                                  NaN                               NaN
# 25%                                  NaN                               NaN
# 50%                                  NaN                               NaN
# 75%                                  NaN                               NaN
# max                                  NaN                               NaN
#
#         customer_zip_code_prefix customer_city customer_state
# ...

# %%
customers.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_city
# sao paulo         15540
# rio de janeiro     6882
# belo horizonte     2773
# brasilia           2131
# curitiba           1521
#                   ...
# ibiara                1
# rio espera            1
# rio dos indios        1
# rio dos cedros        1
# lagoao                1
# Name: customer_id, Length: 4119, dtype: int64

# %%
customers.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False)
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_id, dtype: int64

# %% [markdown]
# ##Explore All Data Order

# %% [markdown]
# Menggabungkan `order_items` & `order_payment`

# %%
order_item_payment = pd.merge(
    left=order_items,
    right=order_payments,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
order_item_payment.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id   price  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   58.90
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36  239.90
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d  199.00
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4   12.99
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87  199.90
#
#    freight_value  payment_sequential payment_type  payment_installments  \
# 0          13.29                 1.0  credit_card                   2.0
# ...

# %% [markdown]
# Menggabungkan `order` & `order_review`

# %%
order = order[order.order_status != "canceled"]

# %%
orders_and_review = pd.merge(
    left=order,
    right=order_review,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
orders_and_review.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp                         review_id  \
# 0    delivered      2017-10-02 10:56:33  a54f0611adc9ed256b57ede6b6eb5114
# 1    delivered      2018-07-24 20:41:37  8d5266042046a06655c8db133d120ba5
# 2    delivered      2018-08-08 08:38:49  e73b67b67587f7644d5bd1a52deb1b01
# 3    delivered      2017-11-18 19:28:06  359d03e676b3c069f62cadba8dd3f6e8
# 4    delivered      2018-02-13 21:18:39  e50934924e227544ba8246aeb3770dd4
#
#    review_score
# 0           4.0
# 1           4.0
# 2           5.0
# 3           5.0
# ...

# %% [markdown]
# Menggabungkan `order_item_payment` & `orders_and_review.head`

# %%
order_all = pd.merge(
    left=order_item_payment,
    right=orders_and_review,
    how="left",
    left_on="order_id",
    right_on="order_id"
)
order_all.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id   price  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202   58.90
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36  239.90
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d  199.00
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4   12.99
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87  199.90
#
#    freight_value  payment_sequential payment_type  payment_installments  \
# 0          13.29                 1.0  credit_card                   2.0
# ...

# %%
order_all.groupby(by="order_status").order_id.count()
# Out:
# order_status
# approved            3
# delivered      115723
# invoiced          376
# processing        376
# shipped          1255
# unavailable         7
# Name: order_id, dtype: int64

# %%
order_all.payment_value.sum()
# Out:
# 20415852.549999997

# %% [markdown]
# ##Explore All Data Product

# %% [markdown]
# Menggabungkan `product_category` & `product`

# %%
product_all = pd.merge(
    left=product_category,
    right=product,
    how="left",
    left_on="product_category_name",
    right_on="product_category_name"
)
product_all.head()
# Out:
#   product_category_name product_category_name_english  \
# 0          beleza_saude                 health_beauty
# 1          beleza_saude                 health_beauty
# 2          beleza_saude                 health_beauty
# 3          beleza_saude                 health_beauty
# 4          beleza_saude                 health_beauty
#
#                          product_id
# 0  e3e020af31d4d89d2602272b315c3f6e
# 1  c5d8079278e912d7e3b6beb48ecb56e8
# 2  36555a2f528d7b2a255c504191445d39
# 3  e586ebb6022265ae1eea38f46ffe3ead
# 4  75b4372e69a42f8ae1d908c076f547b2

# %%
product_all.groupby(by="product_category_name_english").product_id.nunique().sort_values(ascending=False)
# Out:
# product_category_name_english
# bed_bath_table               3029
# sports_leisure               2867
# furniture_decor              2657
# health_beauty                2444
# housewares                   2335
#                              ...
# tablets_printing_image          9
# home_comfort_2                  5
# fashion_childrens_clothes       5
# security_and_services           2
# cds_dvds_musicals               1
# Name: product_id, Length: 71, dtype: int64

# %% [markdown]
# ##Explore `sellers`

# %%
sellers.describe(include="all")
# Out:
#                                seller_id  seller_zip_code_prefix seller_city  \
# count                               3095             3095.000000        3095
# unique                              3095                     NaN         611
# top     3442f8959a84dea7ee197c632cb2df15                     NaN   sao paulo
# freq                                   1                     NaN         694
# mean                                 NaN            32291.059451         NaN
# std                                  NaN            32713.453830         NaN
# min                                  NaN             1001.000000         NaN
# 25%                                  NaN             7093.500000         NaN
# 50%                                  NaN            14940.000000         NaN
# 75%                                  NaN            64552.500000         NaN
# max                                  NaN            99730.000000         NaN
#
#        seller_state
# count          3095
# ...

# %%
sellers.groupby(by="seller_city").seller_id.nunique().sort_values(ascending=False)
# Out:
# seller_city
# sao paulo         694
# curitiba          127
# rio de janeiro     96
# belo horizonte     68
# ribeirao preto     52
#                  ...
# ivoti               1
# itirapina           1
# itau de minas       1
# itapui              1
# xaxim               1
# Name: seller_id, Length: 611, dtype: int64

# %%
sellers.groupby(by="seller_state").seller_id.nunique().sort_values(ascending=False)
# Out:
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# CE      13
# PE       9
# PB       6
# MS       5
# RN       5
# MT       4
# RO       2
# SE       2
# AC       1
# PI       1
# AM       1
# MA       1
# PA       1
# Name: seller_id, dtype: int64

# %% [markdown]
# ##Explore All Data

# %% [markdown]
# Menggabungkan `product_all` & `order_all`

# %%
order_product = pd.merge(
    left=product_all,
    right=order_all,
    how="left",
    left_on="product_id",
    right_on="product_id"
)
order_product.head()
# Out:
#   product_category_name product_category_name_english  \
# 0          beleza_saude                 health_beauty
# 1          beleza_saude                 health_beauty
# 2          beleza_saude                 health_beauty
# 3          beleza_saude                 health_beauty
# 4          beleza_saude                 health_beauty
#
#                          product_id                          order_id  \
# 0  e3e020af31d4d89d2602272b315c3f6e  a41753c6a1d8accb89732e36243432d7
# 1  c5d8079278e912d7e3b6beb48ecb56e8  6a1594b5f5cfc5bac6dcdc3f48f22b5e
# 2  c5d8079278e912d7e3b6beb48ecb56e8  f6fbf7907913892ffc12ada3bff286ba
# 3  36555a2f528d7b2a255c504191445d39  a63144d37a00c28ef382668a5d5ece8b
# 4  e586ebb6022265ae1eea38f46ffe3ead  3ea7135b7064169abacfc10aa72f2e3a
#
#    order_item_id                         seller_id  price  freight_value  \
# 0              1  94144541854e298c2d976cb893b81343   29.9          15.79
# ...

# %% [markdown]
# Menggabungkan `order_product` & `customers`

# %%
order_product_customer = pd.merge(
    left=order_product,
    right=customers,
    how="left",
    left_on="customer_id",
    right_on="customer_id"
)
order_product_customer.head()
# Out:
#   product_category_name product_category_name_english  \
# 0          beleza_saude                 health_beauty
# 1          beleza_saude                 health_beauty
# 2          beleza_saude                 health_beauty
# 3          beleza_saude                 health_beauty
# 4          beleza_saude                 health_beauty
#
#                          product_id                          order_id  \
# 0  e3e020af31d4d89d2602272b315c3f6e  a41753c6a1d8accb89732e36243432d7
# 1  c5d8079278e912d7e3b6beb48ecb56e8  6a1594b5f5cfc5bac6dcdc3f48f22b5e
# 2  c5d8079278e912d7e3b6beb48ecb56e8  f6fbf7907913892ffc12ada3bff286ba
# 3  36555a2f528d7b2a255c504191445d39  a63144d37a00c28ef382668a5d5ece8b
# 4  e586ebb6022265ae1eea38f46ffe3ead  3ea7135b7064169abacfc10aa72f2e3a
#
#    order_item_id                         seller_id  price  freight_value  \
# 0              1  94144541854e298c2d976cb893b81343   29.9          15.79
# ...

# %% [markdown]
# Menggabungkan `order_product_customer` & `sellers`

# %%
all = pd.merge(
    left=order_product_customer,
    right=sellers,
    how="left",
    left_on="seller_id",
    right_on="seller_id"
)
all.head()
# Out:
#   product_category_name product_category_name_english  \
# 0          beleza_saude                 health_beauty
# 1          beleza_saude                 health_beauty
# 2          beleza_saude                 health_beauty
# 3          beleza_saude                 health_beauty
# 4          beleza_saude                 health_beauty
#
#                          product_id                          order_id  \
# 0  e3e020af31d4d89d2602272b315c3f6e  a41753c6a1d8accb89732e36243432d7
# 1  c5d8079278e912d7e3b6beb48ecb56e8  6a1594b5f5cfc5bac6dcdc3f48f22b5e
# 2  c5d8079278e912d7e3b6beb48ecb56e8  f6fbf7907913892ffc12ada3bff286ba
# 3  36555a2f528d7b2a255c504191445d39  a63144d37a00c28ef382668a5d5ece8b
# 4  e586ebb6022265ae1eea38f46ffe3ead  3ea7135b7064169abacfc10aa72f2e3a
#
#    order_item_id                         seller_id  price  freight_value  \
# 0              1  94144541854e298c2d976cb893b81343   29.9          15.79
# ...

# %%
all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116571 entries, 0 to 116570
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   product_category_name          116571 non-null  object
#  1   product_category_name_english  116571 non-null  object
#  2   product_id                     116571 non-null  object
#  3   order_id                       116571 non-null  object
#  4   order_item_id                  116571 non-null  int64
#  5   seller_id                      116571 non-null  object
#  6   price                          116571 non-null  float64
#  7   freight_value                  116571 non-null  float64
#  8   payment_sequential             116568 non-null  float64
#  9   payment_type                   116568 non-null  object
#  10  payment_installments           116568 non-null  float64
#  11  payment_value                  116568 non-null  float64
# ...

# %%
all.dropna(subset="order_purchase_timestamp", inplace=True)

# %%
all.groupby(by="product_category_name_english").agg({
    "product_id": "nunique",
    "price": ["min","max"]
})
# Out:
#                               product_id  price
#                                  nunique    min      max
# product_category_name_english
# agro_industry_and_commerce            74  12.99  2990.00
# air_conditioning                     124  10.90  1599.00
# art                                   53   3.50  6499.00
# arts_and_craftmanship                 19   9.80   289.49
# audio                                 58  14.90   598.99
# ...                                  ...    ...      ...
# stationery                           844   2.29  1693.00
# tablets_printing_image                 9  14.90   889.99
# telephony                           1127   5.00  2428.00
# toys                                1396   4.90  1699.99
# watches_gifts                       1322   8.99  3999.90
#
# [71 rows x 3 columns]

# %%
all.groupby(by="product_category_name_english").agg({
    "order_id": "nunique",
    "payment_value": "sum"
}).sort_values(by="payment_value", ascending=False)
# Out:
#                                order_id  payment_value
# product_category_name_english
# bed_bath_table                     9399     1742703.21
# health_beauty                      8800     1659320.92
# computers_accessories              6654     1585694.42
# furniture_decor                    6425     1438473.73
# watches_gifts                      5604     1423052.08
# ...                                 ...            ...
# flowers                              29        2213.01
# home_comfort_2                       24        1710.54
# cds_dvds_musicals                    12        1199.43
# fashion_childrens_clothes             8         785.67
# security_and_services                 2         324.51
#
# [71 rows x 2 columns]

# %%
all.groupby(by=["product_category_name_english","review_score"]).product_id.nunique()
# Out:
# product_category_name_english  review_score
# agro_industry_and_commerce     1.0               17
#                                2.0                6
#                                3.0               10
#                                4.0               30
#                                5.0               39
#                                                ...
# watches_gifts                  1.0              299
#                                2.0              116
#                                3.0              242
#                                4.0              455
#                                5.0             1004
# Name: product_id, Length: 340, dtype: int64

# %%
all.groupby(by=["customer_state","product_category_name_english"]).agg({
    "order_id": "nunique",
    "payment_value": "sum"
    })
# Out:
#                                               order_id  payment_value
# customer_state product_category_name_english
# AC             auto                                  4         661.91
#                baby                                  3         871.97
#                bed_bath_table                        3        1377.07
#                books_general_interest                2         757.51
#                christmas_supplies                    1         130.85
# ...                                                ...            ...
# TO             sports_leisure                       23        6961.25
#                stationery                            3         350.60
#                telephony                            20        2015.52
#                toys                                 12        2469.97
#                watches_gifts                        27        7274.27
#
# [1356 rows x 2 columns]

# %%
all.to_csv("all_ecommerce.csv", index=False)

# %% [markdown]
# **Insight:**
# - Pada Explore `customer` dapat diambil informasi informasi mengenai banyaknya pelanggan berdasarkan kota dan negara bagian
# - Pada Explore All Data Order dapat diambil informasi mengenai jumlah pesanan berdasarkan statusnya dan jumlah nilai seluruh pesanan
# - Pada Explore All Data Product dapat diambil informasi mengenai jumlah produk berdasarkan tipe produk
# - Pada Explore `sellers` dapat diambil informasi mengenai banyaknya penjual berdasarkan kota dan negara bagian
# - Pada Explore All Data dapat diambil informasi mengenai tipe produk mulai dari berapa jumlah produknya beserta harga terkecil dan terbesarnya, jumlah pemesanan beserta jumlah nilainya, jumlah produk berdasarkan score ratingnya, dan jumlah pemesanan berdasarkan negara bagian beserta jumlah nilai pemesanannya

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1: Bagaimana performa pesanan dalam beberapa bulan?

# %%
all.head()
# Out:
#   product_category_name product_category_name_english  \
# 0          beleza_saude                 health_beauty
# 1          beleza_saude                 health_beauty
# 2          beleza_saude                 health_beauty
# 3          beleza_saude                 health_beauty
# 4          beleza_saude                 health_beauty
#
#                          product_id                          order_id  \
# 0  e3e020af31d4d89d2602272b315c3f6e  a41753c6a1d8accb89732e36243432d7
# 1  c5d8079278e912d7e3b6beb48ecb56e8  6a1594b5f5cfc5bac6dcdc3f48f22b5e
# 2  c5d8079278e912d7e3b6beb48ecb56e8  f6fbf7907913892ffc12ada3bff286ba
# 3  36555a2f528d7b2a255c504191445d39  a63144d37a00c28ef382668a5d5ece8b
# 4  e586ebb6022265ae1eea38f46ffe3ead  3ea7135b7064169abacfc10aa72f2e3a
#
#    order_item_id                         seller_id  price  freight_value  \
# 0              1  94144541854e298c2d976cb893b81343   29.9          15.79
# ...

# %%
monthly_order = all.resample(rule="ME", on="order_purchase_timestamp").agg({
    "order_id": "nunique",
    "payment_value": "sum"
})
monthly_order.index = monthly_order.index.strftime("%Y-%m")
monthly_order = monthly_order.reset_index()
monthly_order.rename(columns={
    "order_id": "order_count",
    "payment_value": "order_value"
}, inplace=True)

# %%
plt.figure(figsize=(10,5))
plt.plot(monthly_order["order_purchase_timestamp"],monthly_order["order_count"], marker="o", linewidth=2, color="blue")
plt.title("Number of Order", loc="center", fontsize=20)
plt.xticks(rotation= 85, fontsize=10)
plt.yticks(fontsize=10)
plt.show()

# %% [markdown]
# ### Pertanyaan 2: Tipe produk apa yang paling banyak dan paling sedikit dipesan?

# %%
type_product = all.groupby(by="product_category_name_english").order_id.nunique().sort_values(ascending=False).reset_index()
type_product.head()
# Out:
#   product_category_name_english  order_id
# 0                bed_bath_table      9399
# 1                 health_beauty      8800
# 2                sports_leisure      7673
# 3         computers_accessories      6654
# 4               furniture_decor      6425

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(24,6))
colors = ["blue", "gray", "gray", "gray","gray"]

sns.barplot(y="product_category_name_english", x="order_id", data=type_product.head(), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("Best Performing Product Type", loc="center", fontsize=15)
ax[0].tick_params(axis="y", labelsize=12)

sns.barplot(y="product_category_name_english", x="order_id", data=type_product.sort_values(by="order_id", ascending=True).head(), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].invert_xaxis()
ax[1].yaxis.set_label_position("right")
ax[1].yaxis.tick_right()
ax[1].set_title("Worst Performing Product Type", loc="center", fontsize=15)
ax[1].tick_params(axis="y", labelsize=12)

plt.suptitle("Best and Worst Performing Type Product by Number of Order", fontsize=20)
plt.show
# Out:
# <ipython-input-171-220930d533cd>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="product_category_name_english", x="order_id", data=type_product.head(), palette=colors, ax=ax[0])
# <ipython-input-171-220930d533cd>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="product_category_name_english", x="order_id", data=type_product.sort_values(by="order_id", ascending=True).head(), palette=colors, ax=ax[1])
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ###Pertanyaan 3: Wilayah mana yang memiliki penjual paling banyak?

# %% [markdown]
# Berdasarkan Kota/City

# %%
seller_bycity = all.groupby(by="seller_city").seller_id.nunique().sort_values(ascending=False).reset_index()
seller_bycity.head()
# Out:
#       seller_city  seller_id
# 0       sao paulo        667
# 1        curitiba        122
# 2  rio de janeiro         94
# 3  belo horizonte         64
# 4  ribeirao preto         51

# %%
plt.figure(figsize=(10,5))
colors = ["blue", "gray", "gray","gray","gray"]

sns.barplot(x="seller_city", y="seller_id", data=seller_bycity.head(5), palette=colors)
plt.ylabel(None)
plt.xlabel(None)
plt.title("Number of Seller by City", loc="center", fontsize=20)
plt.tick_params(axis="x", labelsize=12)

plt.show()
# Out:
# <ipython-input-173-062d18c07945>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="seller_city", y="seller_id", data=seller_bycity.head(5), palette=colors)

# %% [markdown]
# Berdasarkan Negara Bagian/State

# %%
seller_bystate = all.groupby(by="seller_state").seller_id.nunique().sort_values(ascending=False).reset_index()
seller_bystate.head()
# Out:
#   seller_state  seller_id
# 0           SP       1783
# 1           PR        339
# 2           MG        232
# 3           SC        183
# 4           RJ        168

# %%
plt.figure(figsize=(10,5))
colors = ["blue", "gray", "gray","gray","gray"]

sns.barplot(x="seller_state", y="seller_id", data=seller_bystate.head(5), palette=colors)
plt.ylabel(None)
plt.xlabel(None)
plt.title("Number of Seller by State", loc="center", fontsize=20)
plt.tick_params(axis="x", labelsize=12)

plt.show()
# Out:
# <ipython-input-175-6e2043ea0862>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="seller_state", y="seller_id", data=seller_bystate.head(5), palette=colors)

# %% [markdown]
# ###Pertanyaan 4: Bagaimana performa dari penjual terbaik?

# %% [markdown]
# **Berdasarkan Jumlah Pesanan**

# %%
top_seller_byorder = all.groupby(by="seller_id").agg({
    "order_id": "nunique",
    "payment_value": "sum",
    "review_score": "mean"
}).sort_values(by="order_id", ascending=False).reset_index()
top_seller_byorder.rename(columns={
    "order_id": "order_count",
    "payment_value": "revenue"
}, inplace=True)
top_seller_byorder.head()
# Out:
#                           seller_id  order_count    revenue  review_score
# 0  6560211a19b47992c3666cc44a7e94c0         1847  179032.10      3.920114
# 1  4a3ca9315b744ce9f8e9374361493884         1804  305958.14      3.802446
# 2  cc419e0650a3c5ba77189a1882b7556a         1697  143747.57      4.066133
# 3  1f50f920176fa81dab994f9023523100         1403  291851.48      3.984554
# 4  da8622b14eb17ae2831f4ac5b9dab84a         1314  276578.63      4.071256

# %%
plt.figure(figsize=(20,10))
colors = ["blue", "gray", "gray", "gray","gray"]

sns.barplot(y="seller_id", x="order_count", data=top_seller_byorder.head(), palette=colors)
plt.ylabel(None)
plt.xlabel(None)
plt.title("Best Seller by Order Count", loc="center", fontsize=30)
plt.tick_params(axis="y", labelsize=20)
plt.tick_params(axis="x", labelsize=15)

plt.show()
# Out:
# <ipython-input-177-a1f56b0d4f3d>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="seller_id", x="order_count", data=top_seller_byorder.head(), palette=colors)

# %% [markdown]
# Rata-Rata Ratingnya

# %%
plt.figure(figsize=(10,5))
colors = ["blue", "gray", "gray", "gray","gray"]

sns.barplot(x="seller_id", y="review_score", data=top_seller_byorder.head(), palette=colors)
plt.ylabel(None)
plt.xlabel(None)
plt.title("The Average", loc="center", fontsize=15)
plt.tick_params(axis="y", labelsize=10)
plt.tick_params(axis="x", rotation=85, labelsize=12)
plt.show()
# Out:
# <ipython-input-178-6280f340addc>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="seller_id", y="review_score", data=top_seller_byorder.head(), palette=colors)

# %% [markdown]
# Jumlah Pendapatannya

# %%
plt.figure(figsize=(10,5))
colors = ["blue", "gray", "gray", "gray","gray"]

sns.barplot(x="seller_id", y="revenue", data=top_seller_byorder.head(), palette=colors)
plt.ylabel(None)
plt.xlabel(None)
plt.title("The Revenue", loc="center", fontsize=15)
plt.tick_params(axis="x",rotation=85, labelsize=12)
plt.tick_params(axis="y", labelsize=10)
# Out:
# <ipython-input-179-837d5fa4abae>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="seller_id", y="revenue", data=top_seller_byorder.head(), palette=colors)

# %% [markdown]
# **Berdasarkan Jumlah Pendapatan**

# %%
top_seller_byrevenue = all.groupby(by="seller_id").agg({
    "order_id": "nunique",
    "payment_value": "sum",
    "review_score": "mean"
}).sort_values(by="payment_value", ascending=False).reset_index()
top_seller_byrevenue.rename(columns={
    "order_id": "order_count",
    "payment_value": "revenue"
}, inplace=True)
top_seller_byrevenue.head()
# Out:
#                           seller_id  order_count    revenue  review_score
# 0  7c67e1448b00f6e969d365cea6b010ab          982  512645.19      3.394773
# 1  1025f0e2d44d7041d6cf58b6550e0bfa          915  312456.49      3.862116
# 2  4a3ca9315b744ce9f8e9374361493884         1804  305958.14      3.802446
# 3  1f50f920176fa81dab994f9023523100         1403  291851.48      3.984554
# 4  53243585a1d6dc2643021fd1853d8905          358  284903.08      4.071264

# %%
plt.figure(figsize=(20,10))
colors = ["blue", "gray", "gray", "gray","gray"]

sns.barplot(y="seller_id", x="revenue", data=top_seller_byrevenue.head(), palette=colors)
plt.ylabel(None)
plt.xlabel(None)
plt.title("Best Seller", loc="center", fontsize=15)
plt.tick_params(axis="y", labelsize=12)
# Out:
# <ipython-input-181-90e89cbebda0>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="seller_id", x="revenue", data=top_seller_byrevenue.head(), palette=colors)

# %% [markdown]
# Rata-Rata Ratingnya

# %%
plt.figure(figsize=(10,5))
colors = ["blue", "gray", "gray", "gray","gray"]

sns.barplot(x="seller_id", y="review_score", data=top_seller_byrevenue.head(), palette=colors)
plt.ylabel(None)
plt.xlabel(None)
plt.title("The Average", loc="center", fontsize=15)
plt.tick_params(axis="y", labelsize=10)
plt.tick_params(axis="x", rotation=85, labelsize=12)
plt.show()
# Out:
# <ipython-input-182-3d335c2d04a8>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="seller_id", y="review_score", data=top_seller_byrevenue.head(), palette=colors)

# %% [markdown]
# Jumlah Pendapatannya

# %%
plt.figure(figsize=(10,5))
colors = ["blue", "gray", "gray", "gray","gray"]

sns.barplot(x="seller_id", y="revenue", data=top_seller_byrevenue.head(), palette=colors)
plt.ylabel(None)
plt.xlabel(None)
plt.title("The Revenue", loc="center", fontsize=15)
plt.tick_params(axis="x", rotation=85, labelsize=12)
plt.tick_params(axis="y", labelsize=10)
# Out:
# <ipython-input-183-1757affe4540>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="seller_id", y="revenue", data=top_seller_byrevenue.head(), palette=colors)

# %% [markdown]
# ###Pertanyaan 5: Wilayah mana yang memiliki pelanggan paling banyak?

# %% [markdown]
# Berdasarkan Kota/City

# %%
bycity = all.groupby(by="customer_city").customer_id.nunique().sort_values(ascending=False).reset_index()
bycity.head()
# Out:
#     customer_city  customer_id
# 0       sao paulo        15047
# 1  rio de janeiro         6690
# 2  belo horizonte         2689
# 3        brasilia         2081
# 4        curitiba         1487

# %%
plt.figure(figsize=(10,5))
colors = ["blue", "gray", "gray","gray","gray"]

sns.barplot(x="customer_city", y="customer_id", data=bycity.head(5), palette=colors)
plt.ylabel(None)
plt.xlabel(None)
plt.title("Number of Cutomer by City", loc="center", fontsize=20)
plt.tick_params(axis="x", labelsize=12)

plt.show()
# Out:
# <ipython-input-185-e03fdf549774>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="customer_city", y="customer_id", data=bycity.head(5), palette=colors)

# %% [markdown]
# Berdasarkan Negara Bagian/State

# %%
bystate = all.groupby(by="customer_state").customer_id.nunique().sort_values(ascending=False).reset_index()
bystate.head()
# Out:
#   customer_state  customer_id
# 0             SP        40565
# 1             RJ        12506
# 2             MG        11328
# 3             RS         5336
# 4             PR         4912

# %%
plt.figure(figsize=(10,5))
colors = ["blue", "gray", "gray","gray","gray"]

sns.barplot(x="customer_state", y="customer_id", data=bystate.head(5), palette=colors)
plt.ylabel(None)
plt.xlabel(None)
plt.title("Number of Cutomer by State", loc="center", fontsize=20)
plt.tick_params(axis="x", labelsize=12)

plt.show()
# Out:
# <ipython-input-187-39fbe7fc0c56>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="customer_state", y="customer_id", data=bystate.head(5), palette=colors)

# %% [markdown]
# **Insight:**
# - Aktivitas pemesanan mengalami penurunan pada 2016-11, 2017-04, 2017-06, 2017-09, 2017-12, 2018-02, 2018-04, 2018-05, 2018-06, dan 2018-09
# - Tipe produk yang paling banyak dipesan adalah bed_bath_table dan yang paling sedikit dipesan adalah security_and_services
# - Kota dengan penjual terbanyak adalah sao paulo dengan 667 penjual, sedangkan negara bagian dengan penjual terbanyak adalah SP dengan 1783 penjual
# - Penjual terbaik berdasarkan jumlah order adalah 6560211a19b47992c3666cc44a7e94c0 dengan jumlah pesanan 1847, pendapatan 129032.10, dan rata-rata rating 3.9. Sedangkan penjual terbaik berdasarkan jumlah pendapatan adalah 	7c67e1448b00f6e969d365cea6b010ab dengan jumlah order 982, pendapatan 512645.19, dan rata-rata rating 3.39
# - Kota dengan pelanggan terbanyak adalah sao paulo dengan 15047 pelanggan, sedangkan negara bagian dengan pelanggan terbanyak adalah SP 40565 dengan  pelanggan

# %% [markdown]
# ## RFM Analysis

# %%
rfm = all.groupby(by="customer_id", as_index=False).agg({
    "order_purchase_timestamp": "max",
    "order_id": "nunique",
    "payment_value": "sum"
})
rfm.columns = ["customer_id", "max_order_timestamp", "frequency","monetary"]

rfm["max_order_timestamp"] = rfm["max_order_timestamp"].dt.date
recent_date = all["order_purchase_timestamp"].dt.date.max()
rfm["recency"] = rfm["max_order_timestamp"].apply(lambda x: (recent_date - x).days)

rfm.drop("max_order_timestamp", axis=1, inplace=True)

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(30,6))

colors = ["blue", "blue", "blue", "blue", "blue"]

sns.barplot(y="recency", x="customer_id", data=rfm.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
ax[0].set_ylabel(None)
ax[0].set_xlabel(None)
ax[0].set_title("By Recency (days)", loc="center", fontsize=18)
ax[0].tick_params(axis="x", rotation=85, labelsize=15)

sns.barplot(y="frequency", x="customer_id", data=rfm.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
ax[1].set_ylabel(None)
ax[1].set_xlabel(None)
ax[1].set_title("By Frequency", loc="center", fontsize=18)
ax[1].tick_params(axis="x", rotation=85, labelsize=15)

sns.barplot(y="monetary", x="customer_id", data=rfm.sort_values(by="monetary", ascending=False).head(5), palette=colors, ax=ax[2])
ax[2].set_ylabel(None)
ax[2].set_xlabel(None)
ax[2].set_title("By Monetary", loc="center", fontsize=18)
ax[2].tick_params(axis="x", rotation=85, labelsize=15)

plt.suptitle("Best Customer Based on RFM Parameters (customer_id)", fontsize=20)
plt.show()
# Out:
# <ipython-input-189-df4aac80e60a>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="recency", x="customer_id", data=rfm.sort_values(by="recency", ascending=True).head(5), palette=colors, ax=ax[0])
# <ipython-input-189-df4aac80e60a>:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="frequency", x="customer_id", data=rfm.sort_values(by="frequency", ascending=False).head(5), palette=colors, ax=ax[1])
# <ipython-input-189-df4aac80e60a>:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Conclusion pertanyaan 1 = Aktivitas pemesanan mengalami penurunan pada 2016-11, 2017-04, 2017-06, 2017-09, 2017-12, 2018-02, 2018-04, 2018-05, 2018-06, dan 2018-09
# - Conclusion pertanyaan 2 = Tipe produk yang paling banyak dipesan adalah bed_bath_table dan yang paling sedikit dipesan adalah security_and_services
# - Conclusion pertanyaan 3 = Kota dengan penjual terbanyak adalah sao paulo dengan 667 penjual, sedangkan negara bagian dengan penjual terbanyak adalah SP dengan 1783 penjual
# - Conclusion pertanyaan 4 = Penjual terbaik berdasarkan jumlah order adalah 6560211a19b47992c3666cc44a7e94c0 dengan jumlah pesanan 1847, pendapatan 129032.10, dan rata-rata rating 3.9. Sedangkan penjual terbaik berdasarkan jumlah pendapatan adalah 	7c67e1448b00f6e969d365cea6b010ab dengan jumlah order 982, pendapatan 512645.19, dan rata-rata rating 3.39
# - Conclusion pertanyaan 5 = Kota dengan pelanggan terbanyak adalah sao paulo dengan 15047 pelanggan, sedangkan negara bagian dengan pelanggan terbanyak adalah SP 40565 dengan  pelanggan
